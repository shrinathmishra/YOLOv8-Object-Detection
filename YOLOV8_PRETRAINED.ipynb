# %%
print("hello")
# Out:
# hello

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')
model.predict(source='C:\\Users\\shrin\\OneDrive\\Documents\\SHRI PERSONAL\\MySkill\\Projects\\YOLO8 Object Detection\\train\\images\\1_jpeg.rf.23280092eac7e298fb1d498e3c9dd42b.jpg')
# Out:
# image 1/1 C:\Users\shrin\OneDrive\Documents\SHRI PERSONAL\MySkill\Projects\YOLO8 Object Detection\train\images\1_jpeg.rf.23280092eac7e298fb1d498e3c9dd42b.jpg: 640x640 (no detections), 331.7ms
# Speed: 6.5ms preprocess, 331.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...

# %%
from ultralytics import YOLO

model = YOLO()

model.train(data = r"C:\\Users\\shrin\\OneDrive\\Documents\\SHRI PERSONAL\\MySkill\\Projects\\YOLO8 Object Detection\\data.yaml", epochs = 50)
# Out:
# Ultralytics YOLOv8.0.147  Python-3.9.17 torch-2.0.1+cpu CPU (Intel Core(TM) i5-9300H 2.40GHz)
# ...

# %%
# !yolo task=detect mode=predict model="C:\Users\shrin\OneDrive\Documents\SHRI PERSONAL\MySkill\Projects\YOLO8 Object Detection\runs\detect\train3\weights\best.pt" conf=0.25 source="C:\Users\shrin\OneDrive\Documents\SHRI PERSONAL\MySkill\Projects\YOLO8 Object Detection\test\images"
# Out:
# Ultralytics YOLOv8.0.147  Python-3.9.17 torch-2.0.1+cpu CPU (Intel Core(TM) i5-9300H 2.40GHz)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
#
# image 1/55 C:\Users\shrin\OneDrive\Documents\SHRI PERSONAL\MySkill\Projects\YOLO8 Object Detection\test\images\102_jpeg.rf.26fb2ae7abe821cebf8428885e461cdf.jpg: 640x640 1 faucet, 234.4ms
# image 2/55 C:\Users\shrin\OneDrive\Documents\SHRI PERSONAL\MySkill\Projects\YOLO8 Object Detection\test\images\106_jpeg.rf.f7723376d6c8a97d3435110f9f362bf6.jpg: 640x640 1 faucet, 226.4ms
# image 3/55 C:\Users\shrin\OneDrive\Documents\SHRI PERSONAL\MySkill\Projects\YOLO8 Object Detection\test\images\116_jpeg.rf.9fc60a82e7f7521c9ba3b56b2cec4305.jpg: 640x640 1 faucetwater, 219.4ms
# image 4/55 C:\Users\shrin\OneDrive\Documents\SHRI PERSONAL\MySkill\Projects\YOLO8 Object Detection\test\images\120_jpeg.rf.82d90cc650fcf9387a2983e42d503adc.jpg: 640x640 1 faucetwater, 207.1ms
# ...
